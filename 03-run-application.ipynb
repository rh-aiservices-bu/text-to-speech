# %% [markdown]
# ## Flask
# Our API will be served directly from our container using Flask, a popular Python Web Server.
# The Flask application, which will call our prediction function, is defined in the `wsgi.py` file.

# %% [markdown]
# As always, we'll first run some imports to make sure all our requirements are there:

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt

# %% [markdown]
# Now that we have everything in place, we can launch the Flask application.
#
# (Please ignore the CUDA errors of warning if you don't have any GPU).
#
# This cell will be in a **permanent running state**. That's normal as the webserver process will keep running. When you are **finished** with the test you can just select the cell, and click on the **Stop button** (next to Run).

# %%
# !FLASK_ENV=development FLASK_APP=wsgi.py flask run
# Out:
#  * Serving Flask app 'wsgi.py' (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 777-842-596
# 127.0.0.1 - - [05/Apr/2022 22:31:41] "GET /status HTTP/1.1" 200 -
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/universal/libri-tts/fullband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: fullband_melgan
#  > Setting up Audio Processor...
#  | > sample_rate:24000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:/opt/app-root/src/.local/share/tts/vocoder_models--universal--libri-tts--fullband-melgan/scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: fullband_melgan_generator
#  > Discriminator Model: melgan_multiscale_discriminator
#  > Text: "My sprinkler goes like this ststststststststststst and comes back like tttttttttttttttttttttttttttttttttttttttttttttttttte"
#  > Text splitted to sentences.
# ['"My sprinkler goes like this ststststststststststst and comes back like tttttttttttttttttttttttttttttttttttttttttttttttttte"']
# maɪ spɹɪŋklɚ ɡoʊz laɪk ðɪs ststststststststststst ænd kʌmz bæk laɪk tətətətətətətətətətətətətətətətətətətətətətətətt͡ʃ
#  [!] Character '͡' not found in the vocabulary. Discarding it.
#  > interpolating tts model output.
#  > before interpolation : (80, 694)
#  > after interpolation : torch.Size([1, 80, 755])
#  > Processing time: 0.8034923076629639
#  > Real-time factor: 0.08671883753606563
#  > Saving output to tts_output.wav
# 127.0.0.1 - - [05/Apr/2022 22:31:48] "POST /speech HTTP/1.1" 200 -
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/universal/libri-tts/fullband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: fullband_melgan
#  > Setting up Audio Processor...
#  | > sample_rate:24000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:/opt/app-root/src/.local/share/tts/vocoder_models--universal--libri-tts--fullband-melgan/scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: fullband_melgan_generator
#  > Discriminator Model: melgan_multiscale_discriminator
#  > Text: "We hope you have enjoyed our presentation, stick around for any questions"
#  > Text splitted to sentences.
# ['"We hope you have enjoyed our presentation, stick around for any questions"']
# wi hoʊp ju hæv ɪnd͡ʒɔɪd aʊɚ pɹɛzənteɪʃən, stɪk ɚaʊnd fɚ ɛni kwɛst͡ʃənz
#  [!] Character '͡' not found in the vocabulary. Discarding it.
#  > interpolating tts model output.
#  > before interpolation : (80, 434)
#  > after interpolation : torch.Size([1, 80, 472])
#  > Processing time: 0.5196917057037354
#  > Real-time factor: 0.0869069447789055
#  > Saving output to tts_output.wav
# 127.0.0.1 - - [05/Apr/2022 22:31:54] "POST /speech HTTP/1.1" 200 -

# %% [markdown]
# Once the models have been loaded, our server is ready to take requests. Leave this notebook running,and open `04_LPR_test_application.ipynb`.

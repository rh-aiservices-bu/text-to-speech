# %% [markdown]
# ## Flask
# Our API will be served directly from our container using Flask, a popular Python Web Server.
# The Flask application, which will call our prediction function, is defined in the `wsgi.py` file.

# %% [markdown]
# As always, we'll first run some imports to make sure all our requirements are there:

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: Flask==2.0.3 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: TTS==0.6.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: Jinja2>=3.0 in /opt/app-root/lib/python3.8/site-packages (from Flask==2.0.3->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Flask==2.0.3->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Flask==2.0.3->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in /opt/app-root/lib/python3.8/site-packages (from Flask==2.0.3->-r requirements.txt (line 1)) (8.0.3)
# Requirement already satisfied: jieba in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.42.1)
# Requirement already satisfied: matplotlib in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: fsspec>=2021.04.0 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (2021.11.0)
# Requirement already satisfied: pysbd in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.3.4)
# Requirement already satisfied: numpy==1.19.5 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (1.19.5)
# Requirement already satisfied: coqui-trainer in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.0.5)
# Requirement already satisfied: mecab-python3==1.0.3 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: umap-learn==0.5.1 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: coqpit in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.0.15)
# Requirement already satisfied: inflect in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (5.4.0)
# Requirement already satisfied: tqdm in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (4.62.3)
# Requirement already satisfied: librosa==0.8.0 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.8.0)
# Requirement already satisfied: soundfile in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.10.3.post1)
# Requirement already satisfied: tensorboardX in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: numba==0.53 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.53.0)
# Requirement already satisfied: pyworld in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: anyascii in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: cython in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.29.24)
# Requirement already satisfied: gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: pyyaml in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (5.4.1)
# Requirement already satisfied: torchaudio in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: torch>=1.7 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (1.11.0)
# Requirement already satisfied: scipy>=1.4.0 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (1.6.2)
# Requirement already satisfied: webrtcvad in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (2.0.10)
# Requirement already satisfied: pypinyin in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (0.46.0)
# Requirement already satisfied: unidic-lite==1.0.8 in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (1.0.8)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.8/site-packages (from TTS==0.6.0->-r requirements.txt (line 2)) (1.2.4)
# Requirement already satisfied: audioread>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /opt/app-root/lib/python3.8/site-packages (from librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: joblib>=0.14 in /opt/app-root/lib/python3.8/site-packages (from librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: resampy>=0.2.2 in /opt/app-root/lib/python3.8/site-packages (from librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: pooch>=1.0 in /opt/app-root/lib/python3.8/site-packages (from librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /opt/app-root/lib/python3.8/site-packages (from librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.24.1)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from numba==0.53->TTS==0.6.0->-r requirements.txt (line 2)) (60.9.3)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /opt/app-root/lib/python3.8/site-packages (from numba==0.53->TTS==0.6.0->-r requirements.txt (line 2)) (0.36.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/app-root/lib/python3.8/site-packages (from umap-learn==0.5.1->TTS==0.6.0->-r requirements.txt (line 2)) (0.5.6)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.9.1)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.9.7)
# Requirement already satisfied: gruut-ipa~=0.10.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.10.1)
# Requirement already satisfied: num2words<1.0.0,>=0.5.10 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.5.10)
# Requirement already satisfied: dateparser~=1.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: jsonlines~=1.2.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: gruut-lang-sv~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-cs~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-nl~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-ru~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-pt~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-it~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Jinja2>=3.0->Flask==2.0.3->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: cffi>=1.0 in /opt/app-root/lib/python3.8/site-packages (from soundfile->TTS==0.6.0->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: typing-extensions in /opt/app-root/lib/python3.8/site-packages (from torch>=1.7->TTS==0.6.0->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib->TTS==0.6.0->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib->TTS==0.6.0->-r requirements.txt (line 2)) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.8/site-packages (from matplotlib->TTS==0.6.0->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/app-root/lib/python3.8/site-packages (from matplotlib->TTS==0.6.0->-r requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.8/site-packages (from matplotlib->TTS==0.6.0->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->TTS==0.6.0->-r requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboardX->TTS==0.6.0->-r requirements.txt (line 2)) (3.19.1)
# Requirement already satisfied: six in /opt/app-root/lib/python3.8/site-packages (from tensorboardX->TTS==0.6.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: pycparser in /opt/app-root/lib/python3.8/site-packages (from cffi>=1.0->soundfile->TTS==0.6.0->-r requirements.txt (line 2)) (2.21)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.8/site-packages (from dateparser~=1.0.0->gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (4.1)
# Requirement already satisfied: regex!=2019.02.19 in /opt/app-root/lib/python3.8/site-packages (from dateparser~=1.0.0->gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2021.11.10)
# Requirement already satisfied: docopt>=0.6.2 in /opt/app-root/lib/python3.8/site-packages (from num2words<1.0.0,>=0.5.10->gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/app-root/lib/python3.8/site-packages (from pooch>=1.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.26.0)
# Requirement already satisfied: appdirs>=1.3.0 in /opt/app-root/lib/python3.8/site-packages (from pooch>=1.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.8/site-packages (from pooch>=1.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS==0.6.0->-r requirements.txt (line 2)) (3.3)
# Requirement already satisfied: backports.zoneinfo in /opt/app-root/lib/python3.8/site-packages (from tzlocal->dateparser~=1.0.0->gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /opt/app-root/lib/python3.8/site-packages (from tzlocal->dateparser~=1.0.0->gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (0.1.0.post0)
# Requirement already satisfied: tzdata in /opt/app-root/lib/python3.8/site-packages (from pytz-deprecation-shim->tzlocal->dateparser~=1.0.0->gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=2.0.0->TTS==0.6.0->-r requirements.txt (line 2)) (2021.5)

# %% [markdown]
# Now that we have everything in place, we can launch the Flask application.
#
# (Please ignore the CUDA errors of warning if you don't have any GPU).
#
# This cell will be in a **permanent running state**. That's normal as the webserver process will keep running. When you are **finished** with the test you can just select the cell, and click on the **Stop button** (next to Run).

# %%
# !FLASK_ENV=development FLASK_APP=wsgi.py flask run
# Out:
#  * Serving Flask app 'wsgi.py' (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 424-233-601
# 127.0.0.1 - - [05/Apr/2022 19:45:12] "GET /status HTTP/1.1" 200 -
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/universal/libri-tts/fullband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: fullband_melgan
#  > Setting up Audio Processor...
#  | > sample_rate:24000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:/opt/app-root/src/.local/share/tts/vocoder_models--universal--libri-tts--fullband-melgan/scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: fullband_melgan_generator
#  > Discriminator Model: melgan_multiscale_discriminator
#  > Text: "Example speech text: I can say hello"
#  > Text splitted to sentences.
# ['"Example speech text: I can say hello"']
# ɪɡzæmpəl spit͡ʃ tɛkst, aɪ kən seɪ hɛloʊ
#  [!] Character '͡' not found in the vocabulary. Discarding it.
#  > interpolating tts model output.
#  > before interpolation : (80, 262)
#  > after interpolation : torch.Size([1, 80, 285])
#  > Processing time: 0.45131683349609375
#  > Real-time factor: 0.11849323893347385
#  > Saving output to tts_output.wav
# 127.0.0.1 - - [05/Apr/2022 19:45:21] "POST /speech HTTP/1.1" 200 -
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/universal/libri-tts/fullband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: fullband_melgan
#  > Setting up Audio Processor...
#  | > sample_rate:24000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:/opt/app-root/src/.local/share/tts/vocoder_models--universal--libri-tts--fullband-melgan/scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: fullband_melgan_generator
#  > Discriminator Model: melgan_multiscale_discriminator
#  > Text: "Example speech text: I can say hello"
#  > Text splitted to sentences.
# ['"Example speech text: I can say hello"']
# ɪɡzæmpəl spit͡ʃ tɛkst, aɪ kən seɪ hɛloʊ
#  [!] Character '͡' not found in the vocabulary. Discarding it.
#  > interpolating tts model output.
#  > before interpolation : (80, 262)
#  > after interpolation : torch.Size([1, 80, 285])
#  > Processing time: 0.5406303405761719
#  > Real-time factor: 0.14194250106811523
#  > Saving output to tts_output.wav
# 127.0.0.1 - - [05/Apr/2022 19:45:29] "POST /speech HTTP/1.1" 200 -
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/universal/libri-tts/fullband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: fullband_melgan
#  > Setting up Audio Processor...
#  | > sample_rate:24000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:/opt/app-root/src/.local/share/tts/vocoder_models--universal--libri-tts--fullband-melgan/scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: fullband_melgan_generator
#  > Discriminator Model: melgan_multiscale_discriminator
#  > Text: "Example speech text: I can say hello"
#  > Text splitted to sentences.
# ['"Example speech text: I can say hello"']
# ɪɡzæmpəl spit͡ʃ tɛkst, aɪ kən seɪ hɛloʊ
#  [!] Character '͡' not found in the vocabulary. Discarding it.
#  > interpolating tts model output.
#  > before interpolation : (80, 262)
#  > after interpolation : torch.Size([1, 80, 285])
#  > Processing time: 0.5025300979614258
#  > Real-time factor: 0.13193928200668506
#  > Saving output to tts_output.wav
# 127.0.0.1 - - [05/Apr/2022 19:46:40] "POST /speech HTTP/1.1" 200 -
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/universal/libri-tts/fullband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: fullband_melgan
#  > Setting up Audio Processor...
#  | > sample_rate:24000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:/opt/app-root/src/.local/share/tts/vocoder_models--universal--libri-tts--fullband-melgan/scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: fullband_melgan_generator
#  > Discriminator Model: melgan_multiscale_discriminator
#  > Text: "My sprinkler goes like this ststststststststststst and comes back like tttttttttttttttttttttttttttttttttttttttttttttttttte"
#  > Text splitted to sentences.
# ['"My sprinkler goes like this ststststststststststst and comes back like tttttttttttttttttttttttttttttttttttttttttttttttttte"']
# maɪ spɹɪŋklɚ ɡoʊz laɪk ðɪs ststststststststststst ænd kʌmz bæk laɪk tətətətətətətətətətətətətətətətətətətətətətətətt͡ʃ
#  [!] Character '͡' not found in the vocabulary. Discarding it.
#  > interpolating tts model output.
#  > before interpolation : (80, 694)
#  > after interpolation : torch.Size([1, 80, 755])
#  > Processing time: 0.796795129776001
#  > Real-time factor: 0.0859960285239683
#  > Saving output to tts_output.wav
# 127.0.0.1 - - [05/Apr/2022 19:46:48] "POST /speech HTTP/1.1" 200 -

# %% [markdown]
# Once the models have been loaded, our server is ready to take requests. Leave this notebook running,and open `04_LPR_test_application.ipynb`.

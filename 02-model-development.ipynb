# %% [markdown]
# # Let's Develop a TTS model

# %% [markdown]
# In this notebook, we will walk through how to setup and train a machine learning model. Then, we can use a fully-trained model to **speak for us!**
#
# We will use a **pre-trained model** as it takes a **long time** and **lots of data** to train such a model. However, we'll take you though all the steps necessary to train such a tool.
#
# Ready? Let's go!

# %% [markdown]
# ## Import and Config Setup
# We need a lot of imported tools.
#
# We need configuration files for our model and dataset.
# Plus, some key utilities like our Tokenizer and Audio Processor.
#
# Feel free to adjust the model parameters if you are creating your own model, or check out other pre-trained models by running !tts --list_models
#
# Otherwise, simply run the cells below to setup all the model parameters.

# %%
# !pip install gdown
# !gdown --id 1JiCMBVTG4BMREK8cT3MYck1MgYvwASL0 -O models/tts_model.pkl
# !pip install unidecode 
# !pip install phonemizer
import os

# Trainer: Where the ✨️ happens.
# TrainingArgs: Defines the set of arguments of the Trainer.
from trainer import Trainer, TrainerArgs

# GlowTTSConfig: all model related values for training, validating and testing.
from configs.glow_tts_config import GlowTTSConfig

# BaseDatasetConfig: defines name, formatter and path of the dataset.
import torch
from utils.synthesis import synthesis
from utils.more_generic_utils import setup_model
from configs.shared_configs import BaseDatasetConfig
#from utils.tf.io import load_checkpoint
from datasets import load_tts_samples
from models.glow_tts import GlowTts
from utils.text.tokenizer import TTSTokenizer
from utils.audio import AudioProcessor
from utils.text.symbols import symbols
import IPython
import IPython.display as ipd
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=9adb2513785cf8dd0109816f17e69b711cf041e95ad968156112579fb906ab7f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xvggk96h/wheels/7b/7b/5d/656f46cd6889e4c93977be9586901d0adc1271b2d876c84c96
# Successfully built gdown
# ...
# /opt/app-root/lib64/python3.8/site-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1JiCMBVTG4BMREK8cT3MYck1MgYvwASL0
# To: /opt/app-root/src/text-to-speech/models/tts_model.pkl
# 100%|████████████████████████████████████████| 115M/115M [00:01<00:00, 99.1MB/s]
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 87.9 MB/s eta 0:00:00
# ...

# %%
# DEFINE DATASET CONFIG
# Set our new folder as our target dataset and define its path.
# You can also use a simple Dict to define the dataset and for a custom formatter.

output_path = os.path.dirname(os.getcwd())
dataset_config = BaseDatasetConfig(
    name="ljspeech", meta_file_train="metadata.csv", path=os.path.join(output_path, "text-to-speech/datasets/LJSpeech-1.1/")
)

# %%
# we use the same path as this script as our training folder.
output_path = os.path.dirname(os.getcwd())

# INITIALIZE THE TRAINING CONFIGURATION
# Configure the model. Every config class inherits the BaseTTSConfig.
config = GlowTTSConfig(
    model='glow_tts',
    hidden_channels_enc=192,
    hidden_channels_dec=192,
    batch_size=16,
    eval_batch_size=8,
    num_loader_workers=4,
    num_eval_loader_workers=4,
    run_eval=True,
    test_delay_epochs=0,
    epochs=1,
    text_cleaner="phoneme_cleaners",
    use_phonemes=False,
    phoneme_language="en-us",
    phoneme_cache_path=os.path.join(output_path, "text-to-speech/phoneme_cache"),
    print_step=400,
    print_eval=False,
    mixed_precision=True,
    output_path=output_path,
    datasets=[dataset_config],
)

# %% [markdown]
# ## Train the model!
# The model training requires our Dataset and all it's specified parameters
#
# We first iniatize all our tools and functions.
#
# The tokenizer will be used to parse characters into phonemes and a few other transformations to the text.
#
# The ljspeech function is a formatter for this dataset, we can include the function during the data loading!
#
# Before we train the model, we will get a log of parameters and important notes about the model.

# %%
# INITIALIZE THE AUDIO PROCESSOR
# Audio processor is used for feature extraction and audio I/O.
# It mainly serves to the dataloader and the training loggers.
ap = AudioProcessor.init_from_config(config)

# INITIALIZE THE TOKENIZER
# Tokenizer is used to convert text to sequences of token IDs.
# If characters are not defined in the config, default characters are passed to the config
tokenizer, config = TTSTokenizer.init_from_config(config)

#formatter

def ljspeech(root_path, meta_file, **kwargs):  # pylint: disable=unused-argument
    """Normalizes the LJSpeech meta data file to TTS format
    https://keithito.com/LJ-Speech-Dataset/"""
    txt_file = os.path.join(root_path, meta_file)
    items = []
    speaker_name = "ljspeech"
    with open(txt_file, "r", encoding="utf-8") as ttf:
        for line in ttf:
            cols = line.split("|")
            wav_file = os.path.join(root_path, "wavs", cols[0] + ".wav")
            text = cols[2]
            items.append({"text": text, "audio_file": wav_file, "speaker_name": speaker_name})
    return items
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:45
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024

# %%
# LOAD DATA SAMPLES
# Each sample is a list of ```[text, audio_file_path, speaker_name]```
# We use our defined format function for the Ljspeech dataset
train_samples, eval_samples = load_tts_samples(dataset_config, eval_split=True, formatter=ljspeech)

# INITIALIZE THE MODEL
# Models take a config object and a speaker manager as input
# Config defines the details of the model like the number of layers, the size of the embedding, etc.
# Speaker manager is used by multi-speaker models.
model = GlowTTS(config, ap, tokenizer, speaker_manager=None)

# INITIALIZE THE TRAINER
# Trainer provides a generic API to train all the 🐸TTS models with all its perks like mixed-precision training,
# distributed training, etc.
trainer = Trainer(
    TrainerArgs(), config, output_path, model=model, train_samples=train_samples, eval_samples=eval_samples
)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:45
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  | > Found 13100 files in /opt/app-root/src/text-to-speech/datasets/LJSpeech-1.1
#  > Using CUDA: False
#  > Number of GPUs: 0
#
#  > Model has 28610257 parameters

# %% [markdown]
# # AND... 3,2,1... 🚀

# %%
trainer.fit()
# Out:
#  > EPOCH: 0/1
#  --> /opt/app-root/src/run-March-17-2022_11+00PM-9828128
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# | > Number of instances : 12969
#  | > Preprocessing samples
#  | > Max text length: 188
#  | > Min text length: 13
#  | > Avg text length: 100.90014650319993
#  |
#  | > Max audio length: 222643.0
#  | > Min audio length: 24499.0
#  | > Avg audio length: 144984.29755570978
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > TRAINING (2022-03-17 23:01:00)
# /opt/app-root/lib64/python3.8/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# ...

# %% [markdown]
# # Congrats you trained model!
# If you want to now use that model to produce speech, you can include it in the parameters below.
#
# Change the model input to --model_path and additionally add --config_path with the respective file paths. Just like our output_path parameter below.
#
# ## If you're ready to be blown away!
# # Let's hear our machine talk!

# %%
import subprocess
def ttsoutput(textinput):
    t= textinput['data']
    subprocess.run(['tts', "--text", "\"" + t + "\"", '--model_name',"tts_models/en/ljspeech/glow-tts", '--vocoder_name', "vocoder_models/universal/libri-tts/fullband-melgan"])
    return 'tts_output.wav'

# %%
wavefile = ttsoutput({'data':"Hello. I don’t believe we have been introduced. Red Hat Summit? A pleasure to meet you. I am Glow t t s, Human-Cyborg Relations"})

ipd.Audio(filename=wavefile)
# Out:
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/universal/libri-tts/fullband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
# ...

# %% [markdown]
# # Play the audio here ▲
